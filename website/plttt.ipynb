# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

plt.style.use('seaborn')
data = pd.read_csv('MPR.csv')
data
# Out:
#          Date     Expense  Amount
# 0  03-01-2022        Food     250
# 1  05-01-2022     Clothes    1000
# 2  11-01-2022    Earrings     300
# 3  15-01-2022      Fruits     400
# 4  21-01-2022  Stationary     100
# 5  25-01-2022  Travelling     500

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Amount', inplace=True)

p_amt = data['Amount']
p_date=data['Date']
#p_amt = data['Amount']
# try:
#     p_amt = data['Amount']
# except:    
#     p_amt=0
#p_amt

# %%
plt.plot_date(p_amt,p_date, linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title('Monthly Expenditure')
plt.xlabel('Date')
plt.ylabel('Amount')
plt.tight_layout()

plt.show()
